# %% [markdown]
# # FUND

# %% [markdown]
# This runs the FUND model and plots some variables.

# %% [markdown]
# ## Dependencies

# %% [markdown]
# Load dependencies

# %%
using Mimi
using PyPlot

# %% [markdown]
# # Run model

# %%
include("../src/fund.jl");
# Out:
# WARNING: deprecated syntax "[a=>b for (a,b) in c]".
# Use "Dict(a=>b for (a,b) in c)" instead.
#
# WARNING: deprecated syntax "[a=>b for (a,b) in c]".
# Use "Dict(a=>b for (a,b) in c)" instead.

# %%
m = getfund()
run(m)
# Out:
# ch4 atmospheric concentration, '-Inf', unexpectedly less than zero at timestep 2
#
#  in run_timestep(::_mimi_implementation_climatech4cycle.climatech4cycleImpl{Float64}, ::Int64) at /Users/daly/Documents/developer/fund.jl/src/ClimateCH4CycleComponent.jl:33
#  in #run#7(::Int64, ::Function, ::Mimi.Model) at /Users/daly/.julia/v0.5/Mimi/src/Mimi.jl:393
#  in run(::Mimi.Model) at /Users/daly/.julia/v0.5/Mimi/src/Mimi.jl:384

# %% [markdown]
# ## Plot results

# %%
plot(1950:3000, m[:climatedynamics, :temp])
title("temperature")
xlabel("year")
ylabel("°C");
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x32c909390>)

# %%
plot(1950:3000, m[:ocean, :sea])
title("sea-level rise")
xlabel("year")
ylabel("m");
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x327e270d0>)
